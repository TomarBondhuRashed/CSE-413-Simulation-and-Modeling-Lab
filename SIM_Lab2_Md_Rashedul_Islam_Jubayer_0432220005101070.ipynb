# %% [markdown]
# <a href="https://colab.research.google.com/github/TomarBondhuRashed/SIM_Lab2/blob/main/SIM_Lab2_Md_Rashedul_Islam_Jubayer_0432220005101070.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simulation and Modeling Lab
# **Course Code:** CSE 413
# **Academic Level/Term:** 4/1
# **Credit Hour:** 3
# **Course Teacher:** Audity Ghosh, Lecturer, Department of Computer Science and Engineering, University of Information Technology and Sciences (UITS)
#
# **Student Id:** 0432220005101070
#
# **Student Name:** Md. Rashedul Islam Jubayer
#
# **Date:** 28 July, 2025

# %% [markdown]
# #Student's Assignment 1: Basic Matrix Operations

# %%
import numpy as np

# Create two 3×3 matrices with random integers between 1 and 10
A = np.random.randint(1, 11, size=(3, 3))
B = np.random.randint(1, 11, size=(3, 3))

print("Matrix A:\n", A)
print("Matrix B:\n", B)

# Matrix Addition
add_result = A + B
print("\nAddition:\n", add_result)

# Matrix Subtraction
sub_result = A - B
print("\nSubtraction:\n", sub_result)

# Matrix Multiplication
mul_result = A @ B
print("\nMultiplication:\n", mul_result)

# Determinant of A
det_A = np.linalg.det(A)
print("\nDeterminant of A:", det_A)

# Inverse of A (if invertible)
if det_A != 0:
    inv_A = np.linalg.inv(A)
    print("\nInverse of A:\n", inv_A)
else:
    print("\nMatrix A is not invertible (det = 0)")

# Rank of A
rank_A = np.linalg.matrix_rank(A)
print("\nRank of A:", rank_A)
# Out:
# Matrix A:
#  [[ 8  9  1]
#  [10  5  5]
#  [ 4  5  3]]
# Matrix B:
#  [[10  1  4]
#  [ 2 10  5]
#  [ 1  2 10]]
#
# Addition:
#  [[18 10  5]
#  [12 15 10]
#  [ 5  7 13]]
#
# Subtraction:
#  [[-2  8 -3]
#  [ 8 -5  0]
#  [ 3  3 -7]]
#
# Multiplication:
#  [[ 99 100  87]
#  [115  70 115]
#  [ 53  60  71]]
#
# Determinant of A: -140.00000000000006
#
# Inverse of A:
#  [[ 0.07142857  0.15714286 -0.28571429]
#  [ 0.07142857 -0.14285714  0.21428571]
#  [-0.21428571  0.02857143  0.35714286]]
#
# Rank of A: 3

# %% [markdown]
# #Student's Assignment 2: Matrix Plotting and Visualization

# %% [markdown]
# **1.Generate and Plot Two Random Vectors:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Part 1: Generate and Plot Two Random Vectors
vec1 = np.random.rand(15)
vec2 = np.random.rand(15)

plt.figure(figsize=(8, 4))
plt.plot(vec1, label='A', marker='o')
plt.plot(vec2, label='B', marker='s')
plt.title("Random Vectors Comparison")
plt.xlabel("Index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **2.Generate and Visualize a Random Matrix:**

# %%
# Part 2: Generate and Visualize a Random 4x4 Matrix
matrix_4x4 = np.random.rand(4, 4)

plt.figure(figsize=(6, 5))
sns.heatmap(matrix_4x4, annot=True, cmap='viridis', xticklabels=[1,2,3,4], yticklabels=[1,2,3,4])
plt.title("4x4 Random Matrix Heatmap")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %% [markdown]
# **3.Matrix Operations and Visualization:**

# %%
# Part 3: Matrix Operations and Visualization
M1 = np.random.rand(4, 4)
M2 = np.random.rand(4, 4)

# Addition
add_result = M1 + M2

# Subtraction
sub_result = M1 - M2

# Multiplication
mul_result = M1 @ M2

# Flatten each result for bar plot
def plot_matrix_bar(matrix, title):
    flat = matrix.flatten()
    plt.figure(figsize=(6, 4))
    plt.bar(range(len(flat)), flat)
    plt.title(title)
    plt.xlabel("Element Index")
    plt.ylabel("Value")
    plt.grid(True)
    plt.show()

plot_matrix_bar(add_result, "Matrix Addition Result")
plot_matrix_bar(sub_result, "Matrix Subtraction Result")
plot_matrix_bar(mul_result, "Matrix Multiplication Result")
